# %%
from bs4 import BeautifulSoup as bs
import requests
from time import sleep
from pprint import pprint

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54,gzip(gfe)'

# %%
headers = {
    'User-Agent': user_agent
}

# %%
url = 'https://ekaterinburg.hh.ru/vacancies/programmist_python?hhtmFromLabel=rainbow_profession&hhtmFrom=main&customDomain=1'

# %%
def parse_vacancy_hh(dom_vacancy):
    sleep(0.1)
    vacancy_name = dom_vacancy.find('a').text
    
    vacancy_salary = dom_vacancy.find('span', {'class', 'bloko-header-section-3'})
    if vacancy_salary:
        vacancy_salary = vacancy_salary.text
        min_salary, max_salary, currency_salary = clean_salary(vacancy_salary)
    else:
        min_salary, max_salary, currency_salary = None, None, None
            
    vacancy_link = dom_vacancy.find('a')['href']
    
    return {
      'vacancy_name': vacancy_name,
      'vacancy_salary': vacancy_salary,
      'min_salary': min_salary,
      'max_salary': max_salary,
      'currency_salary': currency_salary,
      'vacancy_link': vacancy_link,
      'vacancy_source': 'hh.ru',
    }

# %%
def parse_hh(url_page, headers, result=[], index_page=1):
    response = requests.get(url_page, headers=headers)
    if response.status_code != 200:
        print('Parsing completed')
        return result
    else:
        print(f'Page №{index_page}, link: {response.url}')

    dom = bs(response.content, 'html.parser')
    vacancies = dom.find_all('div', {'class': 'vacancy-serp-item__layout'})
    for vacancy in vacancies:
        result.append(parse_vacancy_hh(vacancy))

    link_next_page = dom.find('a', {'data-qa': 'pager-next'})
    if link_next_page:
        link_next_page = 'https://ekaterinburg.hh.ru' + link_next_page['href']
    else:
        print('Parsing completed')
        return result

    result = parse_hh(link_next_page, headers, result, index_page + 1)   
    return result

# %%
def clean_salary(vacancy_salary_text, min_salary=None, max_salary=None, currency_salary=None):
    list_salary = vacancy_salary_text.replace('\u202f000', ' ').split()
    for i in range(len(list_salary) - 1):
        if list_salary[i] == 'от':
            min_salary = int(list_salary[i + 1])
        elif list_salary[i] == 'до':
            max_salary = int(list_salary[i + 1])
        elif list_salary[i] == '–':
            min_salary = int(list_salary[i - 1])
            max_salary = int(list_salary[i + 1])
    currency_salary = list_salary[-1]
    
    return min_salary, max_salary, currency_salary

# %%
result = parse_hh(url, headers)
# Out:
# Page №1, link: https://ekaterinburg.hh.ru/vacancies/programmist_python?hhtmFromLabel=rainbow_profession&hhtmFrom=main&customDomain=1
# Page №2, link: https://ekaterinburg.hh.ru/vacancies/programmist_python?hhtmFromLabel=rainbow_profession&hhtmFrom=main&customDomain=1&page=1
# Page №3, link: https://ekaterinburg.hh.ru/vacancies/programmist_python?hhtmFromLabel=rainbow_profession&hhtmFrom=main&customDomain=1&page=2
# Parsing completed

# %%
len(result)
# Out:
# 381

# %%
result
# Out:
# [{'vacancy_name': 'Middle Python разработчик',
#   'vacancy_salary': '100\u202f000 – 200\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73444689?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python разработчик',
#   'vacancy_salary': '100\u202f000 – 200\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73712164?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Backend-разработчик на Python',
#   'vacancy_salary': 'от 60\u202f000 руб.',
#   'min_salary': 60000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73112663?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Стажер-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73831046?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python-developer',
#   'vacancy_salary': '150\u202f000 – 220\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 220000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72693020?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/66934335?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python разработчик middle\\senior',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73732381?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python developer (офис)',
#   'vacancy_salary': 'до 100\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/66112913?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python developer',
#   'vacancy_salary': 'от 100\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73860413?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle-Senior Python/Django разработчик',
#   'vacancy_salary': '100\u202f000 – 150\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 150000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73529910?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Backend-разработчик на Python (по работе с BIM моделями Revit)',
#   'vacancy_salary': 'от 80\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73112586?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python разработчик (middle)',
#   'vacancy_salary': 'от 120\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72984440?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий Python-developer',
#   'vacancy_salary': '220\u202f000 – 340\u202f000 руб.',
#   'min_salary': 220000,
#   'max_salary': 340000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72053651?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начинающий специалист по Python направлению (стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73551924?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle Python/Go developer (офис)',
#   'vacancy_salary': 'до 200\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71379712?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle Python (Typescript) Developer',
#   'vacancy_salary': 'от 140\u202f000 руб.',
#   'min_salary': 140000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73696599?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python-разработчик',
#   'vacancy_salary': '120\u202f000 – 190\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': 190000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73011938?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист Python',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/70391903?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист Python+Java/Oracle',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/44174342?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python разработчик (backend)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73177424?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python-разработчик во внутренний каталог сервисов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73523818?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python developer в команду прогнозирования',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73092404?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python-разработчик (внутренние проекты)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73163556?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Наставник курса “Профессия Разработчик на Python”',
#   'vacancy_salary': '40\u202f000 – 80\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 80000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73318478?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle Django разработчик',
#   'vacancy_salary': '100\u202f000 – 100\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 100000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73433195?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior/Lead Python-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74169101?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель группы разработки (Python)',
#   'vacancy_salary': '200\u202f000 – 250\u202f000 руб.',
#   'min_salary': 200000,
#   'max_salary': 250000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73817404?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior системный разработчик (python, Linux)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73443159?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior python developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73702267?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик витрин данных',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/70470301?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист-математик',
#   'vacancy_salary': '100\u202f000 – 180\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 180000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71569973?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Стажер-разработчик Python',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73136494?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73988250?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик DWH (DATA Engineer)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74172861?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps Specialist (DWH)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74149707?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74011518?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик .NET +(либо) Java+(либо) Python',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73905022?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель группы разработки (TeamLead)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73982494?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий инженер группы развития и управления ИТ',
#   'vacancy_salary': '65\u202f000 – 85\u202f000 руб.',
#   'min_salary': 65000,
#   'max_salary': 85000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71552129?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Full-stack Yii2/PHP-разработчик',
#   'vacancy_salary': 'до 200\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73791090?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps-инженер',
#   'vacancy_salary': 'от 250\u202f000 руб.',
#   'min_salary': 250000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73575337?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель по направлениям информационные технологии и робототехника',
#   'vacancy_salary': '42\u202f000 – 45\u202f000 руб.',
#   'min_salary': 42000,
#   'max_salary': 45000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73711401?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий разработчик BI',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73123756?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик / постановщик задач для разработчиков программного обеспечения',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73620469?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-программист АСУ ТП (переезд)',
#   'vacancy_salary': '92\u202f780 – 136\u202f382 руб.',
#   'min_salary': 92780,
#   'max_salary': 136382,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73559973?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior Photonics Engineer (integrated optics, optoelectronics, lasers)',
#   'vacancy_salary': '80\u202f000 – 120\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73598941?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps-инженер в сервис транспорта',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73327168?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Frontend - разработчик на проект DATAPK (angular)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72973041?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior C++ разработчик в Поиск',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72366480?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист (middle)',
#   'vacancy_salary': 'от 80\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71263216?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик / постановщик задач для разработчиков программного обеспечения',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73620469?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-программист АСУ ТП (переезд)',
#   'vacancy_salary': '92\u202f780 – 136\u202f382 руб.',
#   'min_salary': 92780,
#   'max_salary': 136382,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73559973?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Старший разработчик в отдел облачной инфраструктуры',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73438332?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior Photonics Engineer (integrated optics, optoelectronics, lasers)',
#   'vacancy_salary': '80\u202f000 – 120\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': 120000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73598941?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Тимлид в команду разработки на Java',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73443927?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps-инженер в сервис транспорта',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73327168?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Frontend - разработчик на проект DATAPK (angular)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72973041?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями (Волкер)',
#   'vacancy_salary': '15\u202f000 – 39\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': 39000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73493046?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior C++ разработчик в Поиск',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72366480?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист (middle)',
#   'vacancy_salary': 'от 80\u202f000 руб.',
#   'min_salary': 80000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71263216?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71650841?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер Oracle DBA',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73199109?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист (junior)',
#   'vacancy_salary': 'от 50\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71263261?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior Backend Developer',
#   'vacancy_salary': '2\u202f500 – 3\u202f500 USD',
#   'min_salary': 2500,
#   'max_salary': 3500,
#   'currency_salary': 'USD',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73088480?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Программист 1С',
#   'vacancy_salary': '71\u202f000 – 213\u202f000 руб.',
#   'min_salary': 71000,
#   'max_salary': 213000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71920578?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'SRE - инженер в PRM',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/68873612?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior DevOps Engineer (Кипр)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72144215?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий сетевой инженер в ЦОД',
#   'vacancy_salary': '100\u202f000 – 170\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 170000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73177435?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Старший разработчик Go, Tracker',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71673063?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор файловых ресурсов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73093358?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Java разработчик Naumen SMP',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73331737?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/74135458?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python QA Automation (Middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/70666241?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Scala/Java разработчик (Hadoop)',
#   'vacancy_salary': '150\u202f000 – 200\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': 200000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71750200?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps инженер',
#   'vacancy_salary': 'от 110\u202f000 руб.',
#   'min_salary': 110000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/70835673?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Аналитик/Ведущий аналитик DWH',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73035476?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Менеджер IT-проектов внедрения в Контур.Налоговый мониторинг',
#   'vacancy_salary': '100\u202f000 – 160\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': 160000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72674376?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный аналитик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/49454824?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный инженер-программист С/С++',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/50161810?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик бэкенда в Путешествия',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/70824403?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-программист С++ (проект REGUL)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72159260?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер SRE/ DevOps-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73979474?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор Linux AD',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71888473?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Преподаватель робототехники',
#   'vacancy_salary': '25\u202f000 – 40\u202f000 руб.',
#   'min_salary': 25000,
#   'max_salary': 40000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73043398?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69520350?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик на С под Linux (Data Plane)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/51000391?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Тестировщик/QA-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73849621?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Unity разработчик (Middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73838122?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'IT рекрутер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73838114?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Backend разработчик С++ в команду Транспорта',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72747030?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер/Программист микроконтроллеров (стажер)',
#   'vacancy_salary': '19\u202f500 – 24\u202f500 руб.',
#   'min_salary': 19500,
#   'max_salary': 24500,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71871592?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Junior программист 1С',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73779536?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Frontend-разработчик (Angular)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73317351?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начальник Регионального центра развития «Санкт-Петербург»',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73826214?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps - инженер',
#   'vacancy_salary': 'от 150\u202f000 руб.',
#   'min_salary': 150000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73721806?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Frontend-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73725386?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Тестировщик / QA (web, python)',
#   'vacancy_salary': 'от 75\u202f000 руб.',
#   'min_salary': 75000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73721223?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-разработчик',
#   'vacancy_salary': '50\u202f000 – 93\u202f000 руб.',
#   'min_salary': 50000,
#   'max_salary': 93000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72151832?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Specialist DevOps',
#   'vacancy_salary': 'до 280\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 280000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69143099?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'ML-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72111824?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начинающий специалист по .NET направлению (стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73551938?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Эксперт по технологическим вопросам 1С (стажер)',
#   'vacancy_salary': '120\u202f000 – 140\u202f000 руб.',
#   'min_salary': 120000,
#   'max_salary': 140000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71773981?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер DevOps в инфраструктурную команду',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73436867?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69779705?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Старший разработчик в отдел облачной инфраструктуры',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73438332?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями (Волкер)',
#   'vacancy_salary': '15\u202f000 – 39\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': 39000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73493046?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Тимлид в команду разработки на Java',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73443927?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle/Senior Python-разработчик в команду Добычи данных',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/68116288?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Бизнес/Системный аналитик на развитие HR систем',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72036303?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'PHP-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72682316?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Технический писатель',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73379908?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий программист САПР',
#   'vacancy_salary': 'от 100\u202f000 руб.',
#   'min_salary': 100000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73310816?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями (Контест)',
#   'vacancy_salary': '15\u202f000 – 39\u202f000 руб.',
#   'min_salary': 15000,
#   'max_salary': 39000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/48224442?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель IT проектов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73571356?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Архитектор поисковых систем С++',
#   'vacancy_salary': 'от 600\u202f000 руб.',
#   'min_salary': 600000,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72366130?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior QA Engineer (Automation, Python)',
#   'vacancy_salary': 'от 4\u202f500 EUR',
#   'min_salary': 4500,
#   'max_salary': None,
#   'currency_salary': 'EUR',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73233982?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-программист',
#   'vacancy_salary': '40\u202f000 – 65\u202f000 руб.',
#   'min_salary': 40000,
#   'max_salary': 65000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69648239?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': '.Net разработчик / .Net программист (Middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69520432?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер Oracle DBA',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73199109?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Стажер-разработчик .NET',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73136445?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'IOS разработчик мобильных приложений (Middle / Senior)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71845226?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Cпециалист по безопасной разработке (SecDevOps/DevSecOps)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69603312?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик ETL',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71786191?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'PHP разработчик (Middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73070812?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Frontend-разработчик Vue',
#   'vacancy_salary': '90\u202f000 – 160\u202f000 руб.',
#   'min_salary': 90000,
#   'max_salary': 160000,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73012165?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Администратор файловых ресурсов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73093358?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Старший разработчик Go, Tracker',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71673063?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle Python разработчик',
#   'vacancy_salary': '100\u202f000 – 200\u202f000 руб.',
#   'min_salary': 100,
#   'max_salary': 200,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73444689?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python разработчик',
#   'vacancy_salary': '100\u202f000 – 200\u202f000 руб.',
#   'min_salary': 100,
#   'max_salary': 200,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73712164?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Backend-разработчик на Python',
#   'vacancy_salary': 'от 60\u202f000 руб.',
#   'min_salary': 60,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73112663?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Стажер-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73831046?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python-developer',
#   'vacancy_salary': '150\u202f000 – 220\u202f000 руб.',
#   'min_salary': 150,
#   'max_salary': 220,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72693020?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python developer',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/66934335?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python разработчик middle\\senior',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73732381?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python developer (офис)',
#   'vacancy_salary': 'до 100\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 100,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/66112913?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python developer',
#   'vacancy_salary': 'от 100\u202f000 руб.',
#   'min_salary': 100,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73860413?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle-Senior Python/Django разработчик',
#   'vacancy_salary': '100\u202f000 – 150\u202f000 руб.',
#   'min_salary': 100,
#   'max_salary': 150,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73529910?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Backend-разработчик на Python (по работе с BIM моделями Revit)',
#   'vacancy_salary': 'от 80\u202f000 руб.',
#   'min_salary': 80,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73112586?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Python разработчик (middle)',
#   'vacancy_salary': 'от 120\u202f000 руб.',
#   'min_salary': 120,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72984440?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий Python-developer',
#   'vacancy_salary': '220\u202f000 – 340\u202f000 руб.',
#   'min_salary': 220,
#   'max_salary': 340,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72053651?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начинающий специалист по Python направлению (стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73551924?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle Python/Go developer (офис)',
#   'vacancy_salary': 'до 200\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 200,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71379712?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
# ...
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'С++ разработчик в группу качества коммерческих сценариев',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73820802?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'IT рекрутер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73838114?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Backend разработчик С++ в команду Транспорта',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72747030?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер/Программист микроконтроллеров (стажер)',
#   'vacancy_salary': '19\u202f500 – 24\u202f500 руб.',
#   'min_salary': 500,
#   'max_salary': 24,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71871592?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Junior программист 1С',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73779536?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Frontend-разработчик (Angular)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73317351?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начальник Регионального центра развития «Санкт-Петербург»',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73826214?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер СХД',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72456482?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps - инженер',
#   'vacancy_salary': 'от 150\u202f000 руб.',
#   'min_salary': 150,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73721806?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Frontend-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73725386?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Тестировщик / QA (web, python)',
#   'vacancy_salary': 'от 75\u202f000 руб.',
#   'min_salary': 75,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73721223?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-разработчик',
#   'vacancy_salary': '50\u202f000 – 93\u202f000 руб.',
#   'min_salary': 50,
#   'max_salary': 93,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72151832?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Specialist DevOps',
#   'vacancy_salary': 'до 280\u202f000 руб.',
#   'min_salary': None,
#   'max_salary': 280,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69143099?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'ML-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72111824?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'PHP-разработчик с функциями технической поддержки',
#   'vacancy_salary': 'от 150\u202f000 руб.',
#   'min_salary': 150,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73578065?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начинающий специалист по DevOps направлению (стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73551792?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA Automation engineer',
#   'vacancy_salary': 'от 100\u202f000 руб.',
#   'min_salary': 100,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/43670261?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями (TOOLS)',
#   'vacancy_salary': '15\u202f000 – 39\u202f000 руб.',
#   'min_salary': 15,
#   'max_salary': 39,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73595106?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный администратор Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72480824?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начинающий специалист по направлению Unity (стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73551769?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'PHP-разработчик с функциями технической поддержки',
#   'vacancy_salary': 'от 150\u202f000 руб.',
#   'min_salary': 150,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73578065?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начинающий специалист по DevOps направлению (стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73551792?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'QA Automation engineer',
#   'vacancy_salary': 'от 100\u202f000 руб.',
#   'min_salary': 100,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/43670261?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями (TOOLS)',
#   'vacancy_salary': '15\u202f000 – 39\u202f000 руб.',
#   'min_salary': 15,
#   'max_salary': 39,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73595106?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Системный администратор Linux',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72480824?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начинающий специалист по направлению Unity (стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73551769?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Начинающий специалист по .NET направлению (стажер)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73551938?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Эксперт по технологическим вопросам 1С (стажер)',
#   'vacancy_salary': '120\u202f000 – 140\u202f000 руб.',
#   'min_salary': 120,
#   'max_salary': 140,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71773981?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер DevOps в инфраструктурную команду',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73436867?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'DevOps-инженер',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69779705?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Middle/Senior Python-разработчик в команду Добычи данных',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/68116288?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Бизнес/Системный аналитик на развитие HR систем',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72036303?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'PHP-разработчик',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72682316?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Технический писатель',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73379908?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Ведущий программист САПР',
#   'vacancy_salary': 'от 100\u202f000 руб.',
#   'min_salary': 100,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73310816?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Специалист службы поддержки с техническими знаниями (Контест)',
#   'vacancy_salary': '15\u202f000 – 39\u202f000 руб.',
#   'min_salary': 15,
#   'max_salary': 39,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/48224442?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Руководитель IT проектов',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73571356?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Архитектор поисковых систем С++',
#   'vacancy_salary': 'от 600\u202f000 руб.',
#   'min_salary': 600,
#   'max_salary': None,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/72366130?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Senior QA Engineer (Automation, Python)',
#   'vacancy_salary': 'от 4\u202f500 EUR',
#   'min_salary': 4,
#   'max_salary': None,
#   'currency_salary': 'EUR',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73233982?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Инженер-программист',
#   'vacancy_salary': '40\u202f000 – 65\u202f000 руб.',
#   'min_salary': 40,
#   'max_salary': 65,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69648239?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': '.Net разработчик / .Net программист (Middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69520432?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Стажер-разработчик .NET',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73136445?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'IOS разработчик мобильных приложений (Middle / Senior)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71845226?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Cпециалист по безопасной разработке (SecDevOps/DevSecOps)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/69603312?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Разработчик ETL',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/71786191?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'PHP разработчик (Middle)',
#   'vacancy_salary': None,
#   'min_salary': None,
#   'max_salary': None,
#   'currency_salary': None,
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73070812?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'},
#  {'vacancy_name': 'Frontend-разработчик Vue',
#   'vacancy_salary': '90\u202f000 – 160\u202f000 руб.',
#   'min_salary': 90,
#   'max_salary': 160,
#   'currency_salary': 'руб.',
#   'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/73012165?query=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+Python',
#   'vacancy_source': 'hh.ru'}]
